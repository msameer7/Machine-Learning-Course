# %% [markdown]
# # Random Forest Regression

# %% [markdown]
# ## Importing Libraries

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the Dataset

# %%
# Importing the dataset
dataset = pd.read_csv('Poly_dataSet.csv')
X = dataset.iloc[:, 0:1].values
y = dataset.iloc[:, 1].values

# %% [markdown]
# ## Fitting the Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
lin_reg = RandomForestRegressor(n_estimators=10,random_state =0)
lin_reg.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %% [markdown]
# ## Visualization of the Random Forest Regression

# %%
# Visualising the Decision Tree results
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg.predict(X), color = 'blue')
plt.title('Truth or Bluff (RF Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
# Now in this part of the visualization we will plot the mid point values of the givens decision trees values

x_grid=np.arange(min(X),max(X), 0.1)
x_grid =x_grid.reshape(len(x_grid),1)
plt.scatter(X, y, color = 'red')
plt.plot(x_grid, lin_reg.predict(x_grid), color = 'blue')
plt.title('Truth or Bluff (RF Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
